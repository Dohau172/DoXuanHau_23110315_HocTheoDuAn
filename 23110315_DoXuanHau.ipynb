# %% [markdown]
# 5.1. Bài 1. Quản lý sách

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def display_info(self):
        print(f"Tên sách: {self.title}")
        print(f"Tác giả: {self.author}")
        print(f"Năm xuất bản: {self.year}")
        print("-" * 30)

book1 = Book("Dế Mèn Phiêu Lưu Ký", "Tô Hoài", 1941)
book2 = Book("Số Đỏ", "Vũ Trọng Phụng", 1936)

print("--- THÔNG TIN SÁCH ---")
book1.display_info()
book2.display_info()
# Out:
# --- THÔNG TIN SÁCH ---
# Tên sách: Dế Mèn Phiêu Lưu Ký
# Tác giả: Tô Hoài
# Năm xuất bản: 1941
# ------------------------------
# Tên sách: Số Đỏ
# Tác giả: Vũ Trọng Phụng
# Năm xuất bản: 1936
# ------------------------------

# %% [markdown]
# 5.1. Bài 2. Tài khoản ngân hàng

# %%
class BankAccount:
    def __init__(self, account_number, balance=0):
        self._account_number = account_number
        self._balance = balance

    @property
    def account_number(self):
        return self._account_number

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
            print(f"Đã nạp {amount:,} VND. Số dư hiện tại: {self._balance:,} VND")
        else:
            print("Số tiền nạp phải lớn hơn 0!")

    def withdraw(self, amount):
        if 0 < amount <= self._balance:
            self._balance -= amount
            print(f"Đã rút {amount:,} VND. Số dư còn lại: {self._balance:,} VND")
        elif amount > self._balance:
            print("Giao dịch thất bại: Số dư không đủ!")
        else:
            print("Số tiền rút không hợp lệ!")

    def get_balance(self):
        return self._balance

my_acc = BankAccount(account_number="123456789", balance=1000)

print(f"Số tài khoản: {my_acc.account_number}")
print(f"Số dư ban đầu: {my_acc.get_balance():,} VND")

my_acc.deposit(5000)
my_acc.withdraw(2000)
# Out:
# Số tài khoản: 123456789
# Số dư ban đầu: 1,000 VND
# Đã nạp 5,000 VND. Số dư hiện tại: 6,000 VND
# Đã rút 2,000 VND. Số dư còn lại: 4,000 VND

# %% [markdown]
# 5.1. Bài 3. Kế thừa

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"Xin chào, tôi tên là {self.name}, năm nay tôi {self.age} tuổi.")

class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def study(self):
        print(f"Sinh viên {self.name} (MSSV: {self.student_id}) đang chăm chỉ học bài!")

student1 = Student(name="Nguyễn Văn A", age=20, student_id="SV123456")

student1.introduce()
student1.study()
# Out:
# Xin chào, tôi tên là Nguyễn Văn A, năm nay tôi 20 tuổi.
# Sinh viên Nguyễn Văn A (MSSV: SV123456) đang chăm chỉ học bài!

# %% [markdown]
# 5.2.Bài 1.Chia hết cho 3

# %%
gen = (x for x in range(16) if x % 3 == 0)
print(list(gen))
# Out:
# [0, 3, 6, 9, 12, 15]

# %% [markdown]
# 5.2. Bài 2. Dùng next()

# %%
gen = (x for x in range(16) if x % 3 == 0)
first = next(gen)  
print(f"Giá trị đầu tiên: {first}") 
second = next(gen) 
print(f"Giá trị thứ hai: {second}")
# Out:
# Giá trị đầu tiên: 0
# Giá trị thứ hai: 3

# %% [markdown]
# 5.2. Bài tập tổng hợp
# 1.

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25] 

plt.plot(x, y, marker='o', color='b', label='Dữ liệu bình phương')

plt.title("Đồ thị đơn giản")
plt.xlabel("Trục X")
plt.ylabel("Trục Y")
plt.legend()
plt.show()

# %% [markdown]
# 2.

# %%
divisible_by_3_and_5 = [x for x in range(1, 101) if x % 3 == 0 and x % 5 == 0]

print("Các số từ 1-100 chia hết cho cả 3 và 5 là:")
print(divisible_by_3_and_5)
# Out:
# Các số từ 1-100 chia hết cho cả 3 và 5 là:
# [15, 30, 45, 60, 75, 90]

# %% [markdown]
# 3.

# %%
def is_prime(n):
    if n < 2: return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0: return False
    return True

prime_gen = (x for x in range(1, 21) if is_prime(x))

print("Dùng next() để lấy các số nguyên tố:")
try:
    print(next(prime_gen)) 
    print(next(prime_gen)) 
    print(next(prime_gen)) 
    print(next(prime_gen)) 
except StopIteration:
    print("Đã hết danh sách số nguyên tố!")
# Out:
# Dùng next() để lấy các số nguyên tố:
# 2
# 3
# 5
# 7
